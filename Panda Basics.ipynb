# %%
import pandas as pd
import numpy as np

df = pd.read_csv('sample_data.csv')
#df =pd.read_csv('sample_data.csv' , index_col=0) # this will omit the default index column creation by pandas
#df =pd.read_csv('sample_data.csv' , index= ['first','second',....]) #this will create custome made index instead of defualt index values 1,2,...

print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#df = pd.read_csv('PRACTICE.csv')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Load different format data in panda

# %%
#excel format

df_excel = pd.read_excel('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\sample_data.xlsx')
print(df_excel.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#txt format
df_txt = pd.read_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\sample_data.txt')
print(df_txt.head(5))
#txt format will load the data as shown below so we can change this by adding a delimiter 'tab'
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4  4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...

# %%
df_txt = pd.read_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\sample_data.txt',delimiter ='\t')
print(df_txt.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # FIND THE DATA COUNTS

# %%
df.shape # this will give the number of cells in the data
# Out:
# (800, 12)

# %% [markdown]
# # READING DIFFERENT DATAS IN A DATA SETS

# %%
#READ HEADERS
col = df.columns
print(col)
#or print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Read each column
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Read specific column from the dataset
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
#Read  multiple columns
print(df[['Name','Type 1','HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
#Reading  each row
print(df.iloc[2])
#this loaded the third tow ie: all data wrt Venusaur
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
#Reading  multiple rows
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
#Read a specific location ie only venusaur
print (df.iloc[2,1])
# Out:
# Venusaur

# %%
#iterrows command
#iterrows gives as group with heading with each rows data group

for index, row in df.iterrows():
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
#iterrows can be with specific column also
for index ,row in df.iterrows():
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
for index, row in df.iterrows():
    print(index, row['Name':'HP'])  #it will print upto cell 'HP' in iteration

# %%
#loc command, 
#inLOC compared to iloc- the column is indexed with the index value(indexname).....
#instead of index position 
#In iloc column is itered with index position

# %%
df.loc[0:5, ['Type 1']]
#or 
#df.loc[0:5,['Type 1','HP','Attack']]
# Out:
#   Type 1  HP  Attack
# 0  Grass  45      49
# 1  Grass  60      62
# 2  Grass  80      82
# 3  Grass  80     100
# 4   Fire  39      52
# 5   Fire  58      64

# %% [markdown]
# Choosing between LOC and ILOC
# When choosing or transitioning between loc and iloc, there is one "gotcha" worth keeping in mind, which is that the two methods use slightly different indexing schemes.
#
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.
#
# Why the change? Remember that loc can index any stdlib type: strings, for example. If we have a DataFrame with index values Apples, ..., Potatoes, ..., and we want to select "all the alphabetical fruit choices between Apples and Potatoes", then it's a lot more convenient to index df.loc['Apples':'Potatoes'] than it is to index something like df.loc['Apples', 'Potatoet] (t coming after s in the alphabet).
#
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.loc[0:999].
#
# Otherwise, the semantics of using loc are the same as those for iloc.

# %%
#boolean , in below case where ever grass is in Type 1 will give true else false...
#this can be used to iterate the rows with grass 
df['Type 1'] == 'Grass'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
#applying filter in each column  # loc command


df.loc[(df['Type 1'] == "Grass")]
#df.loc[df['Type 1'] == "Fire"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#need to filter grass or fire, in same column OR
df.loc[(df['Type 1'] == "Grass")|(df['Type 1'] == "Fire")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
#to filter from two different columns AND condition
df.loc[(df['Type 1'] == "Grass") & (df['Type 2'] == "Poison")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
#to filter from two different columns OR condition
df.loc[(df['Type 1'] == "Grass") | (df['Type 2'] == "Poison")]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#combining and and or in one statement
#data frame with 'HP greater than 100 for Type 1 grass or Bug.

df_new=df.loc[(df['HP'] >99 ) & ((df['Type 1']== "Grass")|(df['Type 1'] =="Bug"))]

# %%
#Filtering data with other conditions
df_2 =  df.loc[(df['Type 1'] == "Grass") & (df['Defense'] >= 70)]
df_2.to_csv('C:\\Users\\kiran\\Desktop\\extracted.csv')
df_2.head(5) # if we check the index is copied as it is so it is not in order ,
#it follows the previous data set 2,3,49,50,110.....
#to reset this add the command df_2 = df_2.reset_index()
# Out:
#        #                   Name Type 1   Type 2  HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass   Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass   Poison  80     100      123      122
# 49    44                  Gloom  Grass   Poison  60      65       70       85
# 50    45              Vileplume  Grass   Poison  75      80       85      110
# 110  102              Exeggcute  Grass  Psychic  60      40       80       60
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 49        75     40           1      False
# 50        90     50           1      False
# 110       45     40           1      False

# %% [markdown]
# # Pandas Build in Conditional Statements

# %%
#isin 

df.loc[df['Type 1'].isin(['Grass','Bug'])]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 13    10               Caterpie    Bug     NaN   45      30       35       20
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 732  664             Scatterbug    Bug     NaN   38      35       40       27
# 733  665                 Spewpa    Bug     NaN   45      22       60       27
# 734  666               Vivillon    Bug  Flying   80      52       50       90
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
#
# ...

# %%
#notnull

The second is isnull (and its companion notnull). 
These methods let you highlight values which are (or are not) empty (NaN).
For example, to filter out  lacking a value(NaN) in 'Type 1' in the dataset, here's what we would do:

df.loc[df['Type 1'].notnull()]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # FILTERING WITH STRINGS

# %%
#filtering with partial string values eg:Name contains 'Mega'
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
#filtering with partial string values eg:Name without 'Mega' ,then use "~" symbol before after [ .
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %% [markdown]
# https://www.listendata.com/2019/07/how-to-filter-pandas-dataframe.html
#     #USEFULL REFERENCE FOR ALL THE TYPES OF FILTERING

# %% [markdown]
# # FILTERING WITH REGULAR EXPRESSIONS

# %%
  import re  #importing regular expressions

df.loc[df[0'Type 1'].str.contains('Fire|Grass',regex =True)]
#same non case sensitive can be made by  adding flags
df.loc[df['Type 1'].str.contains('Fire|Grass',flags= re.I,regex =True)]
# Out:
#   File "<ipython-input-8-1be4c272f7c9>", line 3
#     df.loc[df[0'Type 1'].str.contains('Fire|Grass',regex =True)]
#                ^
# SyntaxError: invalid syntax

# %%
#contains a string 
df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I,regex =True)]

#starting with a string
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex =True)]

# %%
df_2 = df_2.reset_index() #with this , as new resetted index got added to 0,1,2,3....
df_2.head(5)
#if want to get rid of old index use the command ## df_2 = df_2.reset_index(drop =True) ##

# %%
df_2 = df_2.reset_index(drop=True) 
df_2.head(5)
#df_2.reset_index(drop=True ,inplace =True)  ## this is same as above, but not need to assign df =

# %% [markdown]
# # Describing Data

# %%
df.describe() # it gives the details like mean count, std deviation, min, max etc
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#describe for HP only
df.HP.describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %%
#to get selected columns only for analysis
df[['HP', 'Attack', 'Defense',]].describe()
# Out:
#                HP      Attack     Defense
# count  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500
# std     25.534669   32.457366   31.183501
# min      1.000000    5.000000    5.000000
# 25%     50.000000   55.000000   50.000000
# 50%     65.000000   75.000000   70.000000
# 75%     80.000000  100.000000   90.000000
# max    255.000000  190.000000  230.000000

# %%
#got get only the count, mean.... indivitually
df.count()
#df.mean()
# Out:
# #                  800
# Name               800
# Type 1             800
# Type 2             414
# HP                 800
# Attack             800
# Defense            800
# Sp. Atk            800
# Sp. Def            800
# Speed              800
# Generation         800
# Legendary          800
# index_backwards    800
# dtype: int64

# %%
#get the specific details for specific column 
df.HP.mean()
# Out:
# 69.25875

# %% [markdown]
# # Sorting Data

# %%
df.sort_values('Name')  #default is always ascending

# %%
#extra sorting filter to make it in descending order, if it it True then it became ascending order
df.sort_values('Name',ascending =False)

# %%
#multiple filster if some column datas are  identical
df.sort_values(['Type 1','HP'], ascending =True)

# %%
#in above example one should be ascending another descending     
df.sort_values(['Type 1','HP'],ascending =[True,False])
#this can be writtern as 
df.sort_values(['Type 1','HP'],ascending =[1,0])

# %% [markdown]
# # Update Data

# %%
#Adding a new column  with a default value
df['Total'] = "a" # or an int  df['Total'] = 5
print(df.head(5))

# %%
# Adding colum with value in relation with the existing values
df['Total'] =df['HP'] + df['Attack'] + df['Defense']
print(df.head(5))

# %%
df['index_backwards'] = range(len(df), 0, -1)
df['index_backwards']
# Out:
# 0      800
# 1      799
# 2      798
# 3      797
# 4      796
#       ...
# 795      5
# 796      4
# 797      3
# 798      2
# 799      1
# Name: index_backwards, Length: 800, dtype: int32

# %% [markdown]
# DROPPING OR DELETING DATA

# %%
df =df.drop(columns= ['Total'])
df.head(5)

# %%
#jsut creating a dummy data from scratch
import numpy as np
df1 = pd.DataFrame(np.random.randn(6, 4), columns=list('ABCD'))
print(df1.head(5))

# %%
#Adding new column Total with function iloc

df['Total'] = df.iloc[:,4:10].sum(axis =1)
df.head(5)
#if axis =1 will add horizontaly and axis=0 will add vertically

# %% [markdown]
# CREATING DUPLICATE DATA SET WITH SELECTED DATA

# %%
df1 = df[['Total','HP']]
print(df1.head(5))

# %% [markdown]
# RE-ARRANGING THE COLUMS

# %%
colm = list(df.columns)
df =df[colm[0:4] + [colm[-1]] + [colm[10]] + colm[11:12] + colm[4:10] ]
print(df.head())
#added an additional [] in colm[-1] & colm[10] because only one index there
#hardcoding the numbers like above should be very carefull otherwise it will mess the data

# %% [markdown]
# # Conditional Update

# %%
#replace string using conditions
#df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
#returning back to fire
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

# %%
# changing one columns data with the condition on another column
df.loc[df['Type 1'] =='Fire', 'Legendary'] = 'True'
#This will change the value of legendary True , when the Type 1 is Fire
#print(df.head(10))

# %%
#conditional update for multiple parameters
df.loc[df['Total'] < 500, ['Generation','Legendary']] ='Value is less' #single value for all updated cells 
df.loc[df['Total'] < 500, ['Generation','Legendary']] =['Value is less', 'Value'] #indivitual values for each cells
print(df.head(10))

# %%
df = pd.read_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\sample_data.csv') #calling original data

# %% [markdown]
# # Saving Data

# %%
df.to_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\updated_sample_data.csv')
#above command will save the dataframe 'df' to the mentioned folder with the name 'updated_sample_data.csv'
#this method will save the data with the index number in first column, 
#This is an additional column from panda which was not in original file we start working
#to avoid this use the below method to save data with "index=False" command

# %%
df.to_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\updated_sample_data-1.csv',index =False)

# %%
#saving in excel format
df.to_excel('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\updated_sample_data-1.xlsx',index =False)

# %%
#saving to tab format
#in this no 'delimiter' , instead use 'sep' to seperate the contents
df.to_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\updated_sample_data-1.txt',index =False ,sep='\t')

# %% [markdown]
# # Aggregate Statistics

# %%
df.groupby(['Type 1']).mean()
#adding sort function with aggregate statistics mean
df.groupby(['Type 1']).mean().sort_values('Defense',ascending =False) #grouping in 'Type 1 , sorted according to defence value
df.groupby(['Type 2']).mean().sort_values('Attack',ascending =False) #grouping in 'Type 2' , sorted according to Attack value
#above to find best Attack. below example gives the data for best HP
df.groupby(['Type 2']).mean().sort_values('HP',ascending =False)
# Out:
#                    #         HP      Attack     Defense     Sp. Atk  \
# Type 2
# Fighting  438.192308  79.461538  112.846154   82.500000   81.269231
# Dark      413.850000  75.550000  109.800000   72.050000   81.800000
# Ice       441.285714  90.000000   98.000000   85.642857   92.642857
# Dragon    482.555556  82.166667   94.444444   87.055556   98.500000
# Steel     435.636364  64.636364   92.590909  104.636364   77.727273
# Bug       382.000000  53.333333   90.000000   80.000000   46.666667
# Ground    307.600000  77.228571   89.857143   90.314286   65.542857
# Ghost     551.714286  59.142857   84.142857   82.285714   73.214286
# Rock      347.785714  68.071429   84.000000  126.857143   51.142857
# Fire      481.833333  71.250000   81.250000   80.166667  110.416667
# Flying    331.103093  71.391753   80.288660   68.309278   75.628866
# Psychic   337.151515  72.212121   74.696970   87.030303   88.030303
# Grass     505.400000  62.640000   74.160000   80.120000   60.160000
# ...

# %%
#sum and count
df.groupby(['Type 1']).sum().sort_values('Defense',ascending =False)
df['counts'] =1
#df.head(10)
df.groupby(['Type 1']).count().sort_values('Attack',ascending =False)
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     112   112      53  112     112      112      112      112    112
# Normal     98    98      37   98      98       98       98       98     98
# Grass      70    70      37   70      70       70       70       70     70
# Bug        69    69      52   69      69       69       69       69     69
# Psychic    57    57      19   57      57       57       57       57     57
# Fire       52    52      24   52      52       52       52       52     52
# Electric   44    44      17   44      44       44       44       44     44
# Rock       44    44      35   44      44       44       44       44     44
# Ghost      32    32      22   32      32       32       32       32     32
# Ground     32    32      19   32      32       32       32       32     32
# Dragon     32    32      21   32      32       32       32       32     32
# ...

# %%
df.groupby(['Type 1']).count()['counts']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: counts, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['counts'] # this to squeeze a huge data set
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: counts, Length: 136, dtype: int64

# %% [markdown]
# # Handling Huge Data sets

# %%
for df in pd.read_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\sample_data.csv' , chunksize =5):
    print(df)
    print("next chunk")
    
    #in above case, pandas will load the first 5 datas rows , then next 5  and so on.......
# Out:
#   File "<ipython-input-38-02467fd7c72d>", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Concantiating

# %%
new_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\sample_data.csv' , chunksize =5):
    results =df.groupby(['Type 1']).count()
    
    new_df =pd.concat([new_df, results])

# %% [markdown]
# # CREATING DUMMY DATA  USING PANDA

# %%
import pandas as pd
data = pd.DataFrame({"A" : [5,10], 
                     "MonthSales" : [6,12],"check":[1,2]})
data
data.to_excel('C:\\Users\\kiran\\Desktop\\PANDA_BASICS\\pandas-master\\data.xlsx',index =False)

# %% [markdown]
# # Manipulating the index

# %%
df.set_index("HP")
# Out:
#       #                   Name   Type 1  Type 2  Attack  Defense  Sp. Atk  \
# HP
# 45    1              Bulbasaur    Grass  Poison      49       49       65
# 60    2                Ivysaur    Grass  Poison      62       63       80
# 80    3               Venusaur    Grass  Poison      82       83      100
# 80    3  VenusaurMega Venusaur    Grass  Poison     100      123      122
# 39    4             Charmander     Fire     NaN      52       43       60
# ..  ...                    ...      ...     ...     ...      ...      ...
# 50  719                Diancie     Rock   Fairy     100      150      100
# 50  719    DiancieMega Diancie     Rock   Fairy     160      110      160
# 80  720    HoopaHoopa Confined  Psychic   Ghost     110       60      150
# 80  720     HoopaHoopa Unbound  Psychic    Dark     160       60      170
# 80  721              Volcanion     Fire   Water     110      120      130
#
#     Sp. Def  Speed  Generation  Legendary
# HP
# ...

# %% [markdown]
# # reference video link
# https://www.youtube.com/watch?v=vmEHCJofslg&t=131s

# %% [markdown]
# # Maping in Pandas

# %% [markdown]
# Maps
# A map is a term, borrowed from mathematics,
# for a function that takes one set of values and "maps"
# them to another set of values. In data science we often
# have a need for creating new representations from existing
# to the format that we want it to be in later. Maps are what
# handle this work, making them extremely important for getting your work done!

# %%
HP_mean =df.HP.mean() #calcuate the mean of HP

df.HP #print all the values of HP column

df.HP.map(lambda q:q-HP_mean) #minus df.HP with the mean using map and lambda

"""
In above example first calculate the mean of HP then minum that with
every values of HP , this can be done with map, inside map we use 
lambda function to do this"""

# %% [markdown]
# # Apply function in DF

# %%
"""
Apply function will transform the Data frame , while Map function will 
transform the series
"""
HP_mean =df.HP.mean()


def meanpoint (row):
    row.HP = row.HP-HP_mean
    return row
df.apply(meanpoint, axis ='columns')

# %%
#pandas have many builtin mapping functions
#below is to rename a column

HP_mean =df.HP.mean()
df.HP - HP_mean
# Out:
# 0     -24.25875
# 1      -9.25875
# 2      10.74125
# 3      10.74125
# 4     -30.25875
#          ...
# 795   -19.25875
# 796   -19.25875
# 797    10.74125
# 798    10.74125
# 799    10.74125
# Name: HP, Length: 800, dtype: float64

# %%
#another inbuilt map function in pandas to perform addition of two columns

df.HP +df.Attack
# Out:
# 0       94
# 1      122
# 2      162
# 3      180
# 4       91
#       ...
# 795    150
# 796    210
# 797    190
# 798    240
# 799    190
# Length: 800, dtype: int64
